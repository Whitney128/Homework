# %%
#! pip install citipy

# %%
import matplotlib.pyplot as plt
import json
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as st
from scipy.stats import linregress
from Config import weather_api_key

from citipy import citipy
output_data_file = "output_data/cities.csv"
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
 # List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 600

# %%
city_name = []
lattitude = []
longitude = []
max_temp = []
humidity = []
cloudiness = []
wind_speed = []
country = []
date = []
index_counter = 0
set_counter = 1

# %%
#Perform a weather check on each city using a series of successive API calls.
#Include a print log of each city as it'sbeing processed (with the city number and city name).
print("Beginning Data Retrieval ")
print("-----------------------------")

base_url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{base_url}appid={weather_api_key}&units={units}&q="


# Cities
for index, city in enumerate(cities, start = 1):
    try:
        response = requests.get(query_url + city).json()
        city_name.append(response["name"])
        lattitude.append(response["coord"]["lat"])
        longitude.append(response["coord"]["lon"])
        max_temp.append(response['main']['temp_max'])
        humidity.append(response["main"]["humidity"])
        cloudiness.append(response["clouds"]["all"])
        wind_speed.append(response["wind"]["speed"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        if index_counter > 49:
            index_counter = 0
            set_counter = set_counter + 1
    
        else:
            index_counter = index_counter + 1
            
        print(f"Processing Record {index_counter} of Set {set_counter} : {city}") 
  
    except(KeyError, IndexError):
        
        print("City not found. Skipping...")

print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# City not found. Skipping...
# Processing Record 1 of Set 1 : severnyy
# Processing Record 2 of Set 1 : mataura
# Processing Record 3 of Set 1 : rikitea
# Processing Record 4 of Set 1 : te anau
# Processing Record 5 of Set 1 : chiang rai
# Processing Record 6 of Set 1 : yellowknife
# City not found. Skipping...
# Processing Record 7 of Set 1 : pisco
# Processing Record 8 of Set 1 : bethel
# Processing Record 9 of Set 1 : busselton
# Processing Record 10 of Set 1 : clyde river
# City not found. Skipping...
# Processing Record 11 of Set 1 : souillac
# Processing Record 12 of Set 1 : isangel
# Processing Record 13 of Set 1 : moron
# Processing Record 14 of Set 1 : flinders
# Processing Record 15 of Set 1 : khandyga
# Processing Record 16 of Set 1 : kapaa
# Processing Record 17 of Set 1 : aklavik
# Processing Record 18 of Set 1 : pangody
# Processing Record 19 of Set 1 : new norfolk
# Processing Record 20 of Set 1 : nikolskoye
# Processing Record 21 of Set 1 : vaini
# Processing Record 22 of Set 1 : ushuaia
# Processing Record 23 of Set 1 : butaritari
# City not found. Skipping...
# Processing Record 24 of Set 1 : hervey bay
# Processing Record 25 of Set 1 : puerto ayora
# Processing Record 26 of Set 1 : elat
# Processing Record 27 of Set 1 : bredasdorp
# Processing Record 28 of Set 1 : cape town
# Processing Record 29 of Set 1 : kang
# City not found. Skipping...
# Processing Record 30 of Set 1 : hilo
# Processing Record 31 of Set 1 : fuxin
# City not found. Skipping...
# Processing Record 32 of Set 1 : thompson
# Processing Record 33 of Set 1 : vanimo
# Processing Record 34 of Set 1 : cherskiy
# City not found. Skipping...
# Processing Record 35 of Set 1 : tual
# Processing Record 36 of Set 1 : awjilah
# Processing Record 37 of Set 1 : lodja
# City not found. Skipping...
# Processing Record 38 of Set 1 : nanortalik
# City not found. Skipping...
# Processing Record 39 of Set 1 : port macquarie
# Processing Record 40 of Set 1 : carnarvon
# Processing Record 41 of Set 1 : byurakan
# Processing Record 42 of Set 1 : tiksi
# Processing Record 43 of Set 1 : fortuna
# Processing Record 44 of Set 1 : punta arenas
# Processing Record 45 of Set 1 : cidreira
# Processing Record 46 of Set 1 : roald
# Processing Record 47 of Set 1 : jardim
# Processing Record 48 of Set 1 : labuhan
# Processing Record 49 of Set 1 : hami
# Processing Record 50 of Set 1 : alofi
# Processing Record 0 of Set 2 : knyaze-volkonskoye
# Processing Record 1 of Set 2 : upernavik
# Processing Record 2 of Set 2 : kruisfontein
# Processing Record 3 of Set 2 : port alfred
# Processing Record 4 of Set 2 : chokurdakh
# Processing Record 5 of Set 2 : suntar
# Processing Record 6 of Set 2 : kamaishi
# Processing Record 7 of Set 2 : vilcun
# Processing Record 8 of Set 2 : sitka
# Processing Record 9 of Set 2 : andijon
# Processing Record 10 of Set 2 : ribeira grande
# Processing Record 11 of Set 2 : bure
# Processing Record 12 of Set 2 : san cristobal
# Processing Record 13 of Set 2 : saskylakh
# Processing Record 14 of Set 2 : avarua
# Processing Record 15 of Set 2 : ikalamavony
# Processing Record 16 of Set 2 : torbay
# Processing Record 17 of Set 2 : narsaq
# City not found. Skipping...
# Processing Record 18 of Set 2 : saint-augustin
# Processing Record 19 of Set 2 : albany
# City not found. Skipping...
# Processing Record 20 of Set 2 : lorengau
# Processing Record 21 of Set 2 : mahebourg
# Processing Record 22 of Set 2 : victoria
# Processing Record 23 of Set 2 : barrow
# Processing Record 24 of Set 2 : khorramshahr
# Processing Record 25 of Set 2 : lagoa
# Processing Record 26 of Set 2 : hofn
# Processing Record 27 of Set 2 : palmer
# Processing Record 28 of Set 2 : chumikan
# Processing Record 29 of Set 2 : hithadhoo
# Processing Record 30 of Set 2 : atasu
# Processing Record 31 of Set 2 : samarai
# City not found. Skipping...
# Processing Record 32 of Set 2 : fort nelson
# City not found. Skipping...
# Processing Record 33 of Set 2 : petrokamenskoye
# Processing Record 34 of Set 2 : qaanaaq
# Processing Record 35 of Set 2 : kloulklubed
# City not found. Skipping...
# Processing Record 36 of Set 2 : seoul
# City not found. Skipping...
# Processing Record 37 of Set 2 : san rafael
# Processing Record 38 of Set 2 : saint-philippe
# Processing Record 39 of Set 2 : east london
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 40 of Set 2 : roma
# Processing Record 41 of Set 2 : huarmey
# Processing Record 42 of Set 2 : dawei
# Processing Record 43 of Set 2 : santiago de cao
# Processing Record 44 of Set 2 : talnakh
# Processing Record 45 of Set 2 : jaque
# Processing Record 46 of Set 2 : petropavlovsk-kamchatskiy
# Processing Record 47 of Set 2 : dunedin
# Processing Record 48 of Set 2 : axim
# Processing Record 49 of Set 2 : sabaudia
# Processing Record 50 of Set 2 : luderitz
# Processing Record 0 of Set 3 : yulara
# City not found. Skipping...
# Processing Record 1 of Set 3 : hermanus
# Processing Record 2 of Set 3 : laguna
# Processing Record 3 of Set 3 : chicama
# Processing Record 4 of Set 3 : iqaluit
# Processing Record 5 of Set 3 : tasiilaq
# Processing Record 6 of Set 3 : norman wells
# Processing Record 7 of Set 3 : tuktoyaktuk
# Processing Record 8 of Set 3 : dikson
# Processing Record 9 of Set 3 : provideniya
# Processing Record 10 of Set 3 : batticaloa
# Processing Record 11 of Set 3 : chapais
# Processing Record 12 of Set 3 : yar-sale
# Processing Record 13 of Set 3 : bobon
# Processing Record 14 of Set 3 : srednekolymsk
# Processing Record 15 of Set 3 : grindavik
# Processing Record 16 of Set 3 : houston
# Processing Record 17 of Set 3 : hobart
# Processing Record 18 of Set 3 : tuatapere
# Processing Record 19 of Set 3 : hobyo
# Processing Record 20 of Set 3 : faanui
# Processing Record 21 of Set 3 : hasaki
# Processing Record 22 of Set 3 : khatanga
# Processing Record 23 of Set 3 : walvis bay
# Processing Record 24 of Set 3 : castro
# Processing Record 25 of Set 3 : coihaique
# Processing Record 26 of Set 3 : lebu
# Processing Record 27 of Set 3 : nuqui
# Processing Record 28 of Set 3 : aljezur
# City not found. Skipping...
# Processing Record 29 of Set 3 : pitsunda
# City not found. Skipping...
# Processing Record 30 of Set 3 : biak
# Processing Record 31 of Set 3 : la ronge
# Processing Record 32 of Set 3 : den helder
# Processing Record 33 of Set 3 : semirom
# Processing Record 34 of Set 3 : hambantota
# Processing Record 35 of Set 3 : oda
# Processing Record 36 of Set 3 : mahibadhoo
# City not found. Skipping...
# Processing Record 37 of Set 3 : ketchikan
# Processing Record 38 of Set 3 : sao filipe
# Processing Record 39 of Set 3 : nouadhibou
# Processing Record 40 of Set 3 : urengoy
# Processing Record 41 of Set 3 : rundu
# Processing Record 42 of Set 3 : ust-tsilma
# Processing Record 43 of Set 3 : ponta do sol
# Processing Record 44 of Set 3 : hoquiam
# Processing Record 45 of Set 3 : port hedland
# Processing Record 46 of Set 3 : beyneu
# Processing Record 47 of Set 3 : nabire
# Processing Record 48 of Set 3 : itarema
# Processing Record 49 of Set 3 : bambous virieux
# Processing Record 50 of Set 3 : jamestown
# Processing Record 0 of Set 4 : kaitangata
# Processing Record 1 of Set 4 : homer
# Processing Record 2 of Set 4 : westport
# Processing Record 3 of Set 4 : saint-paul
# Processing Record 4 of Set 4 : nueva italia
# Processing Record 5 of Set 4 : acapulco
# Processing Record 6 of Set 4 : mount hagen
# Processing Record 7 of Set 4 : vila franca do campo
# Processing Record 8 of Set 4 : atuona
# Processing Record 9 of Set 4 : waterloo
# Processing Record 10 of Set 4 : albion
# Processing Record 11 of Set 4 : manado
# City not found. Skipping...
# Processing Record 12 of Set 4 : tessalit
# Processing Record 13 of Set 4 : kupang
# Processing Record 14 of Set 4 : chuy
# Processing Record 15 of Set 4 : iracoubo
# Processing Record 16 of Set 4 : male
# Processing Record 17 of Set 4 : namatanai
# Processing Record 18 of Set 4 : sompeta
# Processing Record 19 of Set 4 : esperance
# Processing Record 20 of Set 4 : bluff
# Processing Record 21 of Set 4 : shubarkuduk
# Processing Record 22 of Set 4 : lewistown
# Processing Record 23 of Set 4 : san jose
# Processing Record 24 of Set 4 : port elizabeth
# Processing Record 25 of Set 4 : lata
# Processing Record 26 of Set 4 : klaksvik
# Processing Record 27 of Set 4 : saint-pierre
# Processing Record 28 of Set 4 : bengkulu
# Processing Record 29 of Set 4 : asau
# Processing Record 30 of Set 4 : cairns
# Processing Record 31 of Set 4 : half moon bay
# Processing Record 32 of Set 4 : katsuura
# Processing Record 33 of Set 4 : ilulissat
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 34 of Set 4 : vestmanna
# Processing Record 35 of Set 4 : kodiak
# Processing Record 36 of Set 4 : ancud
# Processing Record 37 of Set 4 : berlevag
# City not found. Skipping...
# Processing Record 38 of Set 4 : portales
# Processing Record 39 of Set 4 : mar del plata
# Processing Record 40 of Set 4 : agadir
# Processing Record 41 of Set 4 : grafton
# Processing Record 42 of Set 4 : staryy nadym
# City not found. Skipping...
# Processing Record 43 of Set 4 : olinda
# Processing Record 44 of Set 4 : daru
# Processing Record 45 of Set 4 : okitipupa
# Processing Record 46 of Set 4 : barinitas
# Processing Record 47 of Set 4 : yumen
# Processing Record 48 of Set 4 : wagar
# Processing Record 49 of Set 4 : ponta delgada
# Processing Record 50 of Set 4 : rubio
# Processing Record 0 of Set 5 : tumut
# Processing Record 1 of Set 5 : lompoc
# Processing Record 2 of Set 5 : sumenep
# Processing Record 3 of Set 5 : promissao
# City not found. Skipping...
# Processing Record 4 of Set 5 : kimbe
# Processing Record 5 of Set 5 : merauke
# Processing Record 6 of Set 5 : port hardy
# Processing Record 7 of Set 5 : bombay
# Processing Record 8 of Set 5 : inhambane
# City not found. Skipping...
# Processing Record 9 of Set 5 : san patricio
# Processing Record 10 of Set 5 : komsomolskiy
# Processing Record 11 of Set 5 : wanning
# Processing Record 12 of Set 5 : nishihara
# Processing Record 13 of Set 5 : chacabuco
# Processing Record 14 of Set 5 : almetyevsk
# Processing Record 15 of Set 5 : college
# Processing Record 16 of Set 5 : goulburn
# Processing Record 17 of Set 5 : taoudenni
# Processing Record 18 of Set 5 : ambon
# Processing Record 19 of Set 5 : imeni poliny osipenko
# Processing Record 20 of Set 5 : hermiston
# Processing Record 21 of Set 5 : puerto ayacucho
# Processing Record 22 of Set 5 : penzance
# Processing Record 23 of Set 5 : arlit
# Processing Record 24 of Set 5 : constitucion
# Processing Record 25 of Set 5 : ahipara
# Processing Record 26 of Set 5 : noshiro
# Processing Record 27 of Set 5 : mata
# Processing Record 28 of Set 5 : muros
# Processing Record 29 of Set 5 : bac lieu
# Processing Record 30 of Set 5 : progreso
# Processing Record 31 of Set 5 : guerrero negro
# Processing Record 32 of Set 5 : yerbogachen
# Processing Record 33 of Set 5 : ust-nera
# Processing Record 34 of Set 5 : illela
# City not found. Skipping...
# Processing Record 35 of Set 5 : cayenne
# Processing Record 36 of Set 5 : dolgoye
# Processing Record 37 of Set 5 : mantua
# Processing Record 38 of Set 5 : arraial do cabo
# Processing Record 39 of Set 5 : edendale
# Processing Record 40 of Set 5 : leningradskiy
# Processing Record 41 of Set 5 : touros
# Processing Record 42 of Set 5 : najran
# Processing Record 43 of Set 5 : olot
# Processing Record 44 of Set 5 : sioux lookout
# Processing Record 45 of Set 5 : bandarbeyla
# Processing Record 46 of Set 5 : adrar
# Processing Record 47 of Set 5 : niamey
# Processing Record 48 of Set 5 : sabang
# Processing Record 49 of Set 5 : hamilton
# Processing Record 50 of Set 5 : qazax
# Processing Record 0 of Set 6 : severo-kurilsk
# Processing Record 1 of Set 6 : georgetown
# Processing Record 2 of Set 6 : tingo maria
# Processing Record 3 of Set 6 : tutoia
# Processing Record 4 of Set 6 : airai
# Processing Record 5 of Set 6 : mount isa
# Processing Record 6 of Set 6 : saint-georges
# Processing Record 7 of Set 6 : kuntaur
# Processing Record 8 of Set 6 : villarrobledo
# Processing Record 9 of Set 6 : nantucket
# City not found. Skipping...
# Processing Record 10 of Set 6 : mosquera
# Processing Record 11 of Set 6 : sechura
# Processing Record 12 of Set 6 : zaysan
# Processing Record 13 of Set 6 : chiang khong
# Processing Record 14 of Set 6 : coquimbo
# Processing Record 15 of Set 6 : naze
# Processing Record 16 of Set 6 : queenstown
# Processing Record 17 of Set 6 : sinnamary
# Processing Record 18 of Set 6 : punta alta
# Processing Record 19 of Set 6 : el jicaro
# Processing Record 20 of Set 6 : santa cruz
# Processing Record 21 of Set 6 : ukiah
# Processing Record 22 of Set 6 : naberera
# Processing Record 23 of Set 6 : surgana
# Processing Record 24 of Set 6 : hudson bay
# Processing Record 25 of Set 6 : hastings
# Processing Record 26 of Set 6 : fairbanks
# Processing Record 27 of Set 6 : pemangkat
# Processing Record 28 of Set 6 : foeni
# Processing Record 29 of Set 6 : amga
# Processing Record 30 of Set 6 : kananga
# Processing Record 31 of Set 6 : yuncheng
# Processing Record 32 of Set 6 : nagato
# Processing Record 33 of Set 6 : basco
# Processing Record 34 of Set 6 : pitea
# Processing Record 35 of Set 6 : kasiri
# Processing Record 36 of Set 6 : phan thiet
# Processing Record 37 of Set 6 : wattegama
# Processing Record 38 of Set 6 : neuquen
# Processing Record 39 of Set 6 : izumo
# City not found. Skipping...
# Processing Record 40 of Set 6 : aranos
# Processing Record 41 of Set 6 : bolhrad
# Processing Record 42 of Set 6 : katsina
# Processing Record 43 of Set 6 : san policarpo
# Processing Record 44 of Set 6 : cap-aux-meules
# Processing Record 45 of Set 6 : noumea
# Processing Record 46 of Set 6 : laje
# Processing Record 47 of Set 6 : caravelas
# Processing Record 48 of Set 6 : nadvoitsy
# Processing Record 49 of Set 6 : abu dhabi
# Processing Record 50 of Set 6 : oistins
# Processing Record 0 of Set 7 : atar
# Processing Record 1 of Set 7 : svetlyy
# Processing Record 2 of Set 7 : comodoro rivadavia
# Processing Record 3 of Set 7 : sola
# Processing Record 4 of Set 7 : mareeba
# Processing Record 5 of Set 7 : luanda
# Processing Record 6 of Set 7 : west wendover
# Processing Record 7 of Set 7 : lokosovo
# Processing Record 8 of Set 7 : bani
# Processing Record 9 of Set 7 : vila velha
# Processing Record 10 of Set 7 : pundaguitan
# Processing Record 11 of Set 7 : rio gallegos
# Processing Record 12 of Set 7 : trinidad
# Processing Record 13 of Set 7 : puerto escondido
# Processing Record 14 of Set 7 : ushumun
# Processing Record 15 of Set 7 : seymchan
# Processing Record 16 of Set 7 : maniitsoq
# Processing Record 17 of Set 7 : kaeo
# Processing Record 18 of Set 7 : maldonado
# Processing Record 19 of Set 7 : worthington
# Processing Record 20 of Set 7 : perth
# Processing Record 21 of Set 7 : mogadishu
# Processing Record 22 of Set 7 : grand gaube
# Processing Record 23 of Set 7 : tsiroanomandidy
# Processing Record 24 of Set 7 : emerald
# Processing Record 25 of Set 7 : christchurch
# Processing Record 26 of Set 7 : chitral
# Processing Record 27 of Set 7 : husavik
# Processing Record 28 of Set 7 : lavrentiya
# Processing Record 29 of Set 7 : eydhafushi
# Processing Record 30 of Set 7 : burnie
# Processing Record 31 of Set 7 : puerto colombia
# Processing Record 32 of Set 7 : chake chake
# Processing Record 33 of Set 7 : poronaysk
# Processing Record 34 of Set 7 : dingli
# Processing Record 35 of Set 7 : pierre
# Processing Record 36 of Set 7 : kargat
# Processing Record 37 of Set 7 : camacupa
# Processing Record 38 of Set 7 : sault sainte marie
# Processing Record 39 of Set 7 : ruidoso
# Processing Record 40 of Set 7 : mendi
# Processing Record 41 of Set 7 : shushtar
# Processing Record 42 of Set 7 : nemuro
# Processing Record 43 of Set 7 : bryan
# Processing Record 44 of Set 7 : waddan
# Processing Record 45 of Set 7 : bokoro
# Processing Record 46 of Set 7 : ginir
# Processing Record 47 of Set 7 : marawi
# Processing Record 48 of Set 7 : mount pleasant
# Processing Record 49 of Set 7 : jadu
# Processing Record 50 of Set 7 : manokwari
# Processing Record 0 of Set 8 : acarau
# Processing Record 1 of Set 8 : nioro
# Processing Record 2 of Set 8 : beringovskiy
# Processing Record 3 of Set 8 : montlucon
# Processing Record 4 of Set 8 : gisborne
# Processing Record 5 of Set 8 : black river
# Processing Record 6 of Set 8 : blackfoot
# Processing Record 7 of Set 8 : staszow
# Processing Record 8 of Set 8 : panzhihua
# Processing Record 9 of Set 8 : bilma
# Processing Record 10 of Set 8 : montepuez
# Processing Record 11 of Set 8 : russell
# Processing Record 12 of Set 8 : saint-francois
# Processing Record 13 of Set 8 : sayyan
# City not found. Skipping...
# Processing Record 14 of Set 8 : umm kaddadah
# Processing Record 15 of Set 8 : la grande
# Processing Record 16 of Set 8 : mount gambier
# Processing Record 17 of Set 8 : cururupu
# Processing Record 18 of Set 8 : chateaubelair
# Processing Record 19 of Set 8 : turbat
# Processing Record 20 of Set 8 : dingle
# Processing Record 21 of Set 8 : waipawa
# Processing Record 22 of Set 8 : alandur
# Processing Record 23 of Set 8 : freeport
# Processing Record 24 of Set 8 : anadyr
# Processing Record 25 of Set 8 : kavaratti
# City not found. Skipping...
# Processing Record 26 of Set 8 : melfi
# Processing Record 27 of Set 8 : marseille
# Processing Record 28 of Set 8 : ushtobe
# Processing Record 29 of Set 8 : sardinata
# Processing Record 30 of Set 8 : kosa
# Processing Record 31 of Set 8 : lakes entrance
# Processing Record 32 of Set 8 : mandalgovi
# Processing Record 33 of Set 8 : carutapera
# Processing Record 34 of Set 8 : gornyy
# Processing Record 35 of Set 8 : sovetskiy
# Processing Record 36 of Set 8 : salalah
# Processing Record 37 of Set 8 : port blair
# Processing Record 38 of Set 8 : sanming
# Processing Record 39 of Set 8 : chifeng
# Processing Record 40 of Set 8 : tucupita
# Processing Record 41 of Set 8 : faya
# Processing Record 42 of Set 8 : beeville
# Processing Record 43 of Set 8 : tera
# Processing Record 44 of Set 8 : mwene-ditu
# Processing Record 45 of Set 8 : ust-maya
# City not found. Skipping...
# Processing Record 46 of Set 8 : portland
# Processing Record 47 of Set 8 : meulaboh
# Processing Record 48 of Set 8 : adra
# Processing Record 49 of Set 8 : kroya
# Processing Record 50 of Set 8 : lilongwe
# Processing Record 0 of Set 9 : chute-aux-outardes
# Processing Record 1 of Set 9 : isla vista
# City not found. Skipping...
# Processing Record 2 of Set 9 : mangochi
# City not found. Skipping...
# Processing Record 3 of Set 9 : oshogbo
# Processing Record 4 of Set 9 : igdir
# Processing Record 5 of Set 9 : totness
# Processing Record 6 of Set 9 : churapcha
# Processing Record 7 of Set 9 : jalu
# Processing Record 8 of Set 9 : saldanha
# Processing Record 9 of Set 9 : sistranda
# Processing Record 10 of Set 9 : banda aceh
# Processing Record 11 of Set 9 : kununurra
# Processing Record 12 of Set 9 : bosaso
# Processing Record 13 of Set 9 : sangar
# Processing Record 14 of Set 9 : horsham
# Processing Record 15 of Set 9 : itoman
# Processing Record 16 of Set 9 : liepaja
# Processing Record 17 of Set 9 : ambilobe
# Processing Record 18 of Set 9 : kirakira
# Processing Record 19 of Set 9 : dyersburg
# Processing Record 20 of Set 9 : tete
# Processing Record 21 of Set 9 : port-gentil
# Processing Record 22 of Set 9 : el paujil
# Processing Record 23 of Set 9 : coahuayana
# Processing Record 24 of Set 9 : sabha
# Processing Record 25 of Set 9 : irara
# Processing Record 26 of Set 9 : praia
# Processing Record 27 of Set 9 : sao joao da barra
# Processing Record 28 of Set 9 : feijo
# Processing Record 29 of Set 9 : maragogi
# Processing Record 30 of Set 9 : poum
# Processing Record 31 of Set 9 : sal rei
# Processing Record 32 of Set 9 : terme
# Processing Record 33 of Set 9 : thinadhoo
# Processing Record 34 of Set 9 : coos bay
# Processing Record 35 of Set 9 : kyle
# Processing Record 36 of Set 9 : turayf
# Processing Record 37 of Set 9 : khandagayty
# Processing Record 38 of Set 9 : millinocket
# Processing Record 39 of Set 9 : sept-iles
# Processing Record 40 of Set 9 : ilhabela
# Processing Record 41 of Set 9 : tromso
# Processing Record 42 of Set 9 : ixtapa
# Processing Record 43 of Set 9 : turukhansk
# Processing Record 44 of Set 9 : wilmington
# Processing Record 45 of Set 9 : darnah
# Processing Record 46 of Set 9 : ola
# Processing Record 47 of Set 9 : piacabucu
# Processing Record 48 of Set 9 : caernarfon
# Processing Record 49 of Set 9 : geraldton
# Processing Record 50 of Set 9 : kavieng
# Processing Record 0 of Set 10 : kukmor
# Processing Record 1 of Set 10 : vao
# Processing Record 2 of Set 10 : lincoln
# Processing Record 3 of Set 10 : gazalkent
# Processing Record 4 of Set 10 : monrovia
# Processing Record 5 of Set 10 : manono
# Processing Record 6 of Set 10 : longyearbyen
# Processing Record 7 of Set 10 : veshkayma
# Processing Record 8 of Set 10 : cabo san lucas
# Processing Record 9 of Set 10 : tautira
# Processing Record 10 of Set 10 : abonnema
# Processing Record 11 of Set 10 : vaxjo
# Processing Record 12 of Set 10 : havre-saint-pierre
# Processing Record 13 of Set 10 : abaza
# City not found. Skipping...
# Processing Record 14 of Set 10 : porto novo
# Processing Record 15 of Set 10 : houma
# Processing Record 16 of Set 10 : lerwick
# Processing Record 17 of Set 10 : xixiang
# Processing Record 18 of Set 10 : bathsheba
# Processing Record 19 of Set 10 : nome
# Processing Record 20 of Set 10 : umm lajj
# Processing Record 21 of Set 10 : jiuquan
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 22 of Set 10 : shelburne
# Processing Record 23 of Set 10 : santa rosa
# Processing Record 24 of Set 10 : brewster
# Processing Record 25 of Set 10 : jawhar
# City not found. Skipping...
# Processing Record 26 of Set 10 : viransehir
# Processing Record 27 of Set 10 : buin
# Processing Record 28 of Set 10 : belle fourche
# Processing Record 29 of Set 10 : mamit
# Processing Record 30 of Set 10 : naifaru
# Processing Record 31 of Set 10 : korla
# Processing Record 32 of Set 10 : urdoma
# Processing Record 33 of Set 10 : aykhal
# Processing Record 34 of Set 10 : kensington
# Processing Record 35 of Set 10 : broken hill
# Processing Record 36 of Set 10 : lianran
# Processing Record 37 of Set 10 : tyup
# Processing Record 38 of Set 10 : northam
# City not found. Skipping...
# Processing Record 39 of Set 10 : gizo
# Processing Record 40 of Set 10 : nosy varika
# Processing Record 41 of Set 10 : darovskoy
# Processing Record 42 of Set 10 : vestmannaeyjar
# Processing Record 43 of Set 10 : humberto de campos
# Processing Record 44 of Set 10 : yarmouth
# Processing Record 45 of Set 10 : pangnirtung
# Processing Record 46 of Set 10 : thunder bay
# Processing Record 47 of Set 10 : itaituba
# Processing Record 48 of Set 10 : vylkove
# Processing Record 49 of Set 10 : qaqortoq
# Processing Record 50 of Set 10 : harper
# Processing Record 0 of Set 11 : tiznit
# Processing Record 1 of Set 11 : alekseyevka
# Processing Record 2 of Set 11 : ust-kuyga
# Processing Record 3 of Set 11 : pevek
# City not found. Skipping...
# Processing Record 4 of Set 11 : bograd
# Processing Record 5 of Set 11 : channel-port aux basques
# Processing Record 6 of Set 11 : kamenka
# City not found. Skipping...
# Processing Record 7 of Set 11 : misratah
# Processing Record 8 of Set 11 : laurinburg
# Processing Record 9 of Set 11 : north bend
# City not found. Skipping...
# Processing Record 10 of Set 11 : phalombe
# Processing Record 11 of Set 11 : naliya
# Processing Record 12 of Set 11 : pasni
# Processing Record 13 of Set 11 : baruun-urt
# Processing Record 14 of Set 11 : tel aviv-yafo
# Processing Record 15 of Set 11 : erzin
# Processing Record 16 of Set 11 : iquique
# Processing Record 17 of Set 11 : jumla
# Processing Record 18 of Set 11 : angermunde
# Processing Record 19 of Set 11 : otradnoye
# Processing Record 20 of Set 11 : wakkanai
# Processing Record 21 of Set 11 : virginia beach
# Processing Record 22 of Set 11 : codrington
# Processing Record 23 of Set 11 : nakhon phanom
# Processing Record 24 of Set 11 : calamar
# Processing Record 25 of Set 11 : saint anthony
# City not found. Skipping...
# Processing Record 26 of Set 11 : alyangula
# Processing Record 27 of Set 11 : pinega
# Processing Record 28 of Set 11 : north platte
# Processing Record 29 of Set 11 : miraflores
# Processing Record 30 of Set 11 : amiens
# Processing Record 31 of Set 11 : bundaberg
# City not found. Skipping...
# Processing Record 32 of Set 11 : quatre cocos
# Processing Record 33 of Set 11 : alice springs
# Processing Record 34 of Set 11 : doha
# Processing Record 35 of Set 11 : bantry
# City not found. Skipping...
# Processing Record 36 of Set 11 : kuching
# Processing Record 37 of Set 11 : guozhen
# Processing Record 38 of Set 11 : kasama
# Processing Record 39 of Set 11 : mezhdurechenskiy
# Processing Record 40 of Set 11 : slave lake
# Processing Record 41 of Set 11 : baykit
# Processing Record 42 of Set 11 : menongue
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
weather_df = pd.DataFrame({ 
                "City" : city_name,
                "Lat" : lattitude,
                "Lng" : longitude,
                "Max Temp" : max_temp,
                "Humidity" : humidity,
                "Cloudiness" : cloudiness,
                "Wind Speed" : wind_speed,
                "Country" : country,
                "Date" : date,
})

# %%
#Export the city data into a .csv.
weather_df.count()
# Out:
# City          552
# Lat           552
# Lng           552
# Max Temp      552
# Humidity      552
# Cloudiness    552
# Wind Speed    552
# Country       552
# Date          552
# dtype: int64

# %%
#.csv
weather_df.to_csv("output_data/cities.csv", index = False)

# %%
#Display the DataFrame
weather_df.head()
# Out:
#          City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    Severnyy  50.68   36.55     60.80        72          61        4.47
# 1     Mataura -46.19  168.86     46.51        87          99        4.92
# 2     Rikitea -23.12 -134.97     68.74        77           0       20.83
# 3     Te Anau -45.42  167.72     45.21        82          96        6.49
# 4  Chiang Rai  19.91   99.83     87.80        74          20        4.70
#
#   Country        Date
# 0      RU  1595653718
# 1      NZ  1595653718
# 2      PF  1595653718
# 3      NZ  1595653719
# 4      TH  1595653427

# %%
 #Inspect the data and remove the cities where the humidity > 100%.

#Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %%
# Extract relevant fields from the data frame


# Export the City_Data into a csv

# %%
 #Latitude vs. Temperature Plot
    
plt.scatter(weather_df["Lat"], weather_df["Max Temp"], facecolor = "steelblue", edgecolor = "black")

plt.title("City Latitude vs. Max Temperature (04/01/20)")
plt.xlabel("Laitude")
plt.ylabel("Max Temperature (F)")
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# Save the plotted figure as .pngs
plt.savefig("Latitude vs Max Temperature.png")

# %%
#Latitude vs. Humidity Plot

plt.scatter(weather_df["Lat"], weather_df["Humidity"], facecolor = "steelblue", edgecolor = "black")

plt.title("City Latitude vs. Humidity (04/01/20)")
plt.xlabel("Laitude")
plt.ylabel("Humidity (%)")
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# Save the plotted figure as .pngs
plt.savefig("Latitude vs Humidity.png")

# %%
 #Latitude vs. Cloudiness Plot
plt.scatter(weather_df["Lat"], weather_df["Cloudiness"], facecolor = "steelblue", edgecolor = "black")

plt.title("City Latitude vs. Cloudiness (04/01/20)")
plt.xlabel("Laitude")
plt.ylabel("Cloudiness (%)")
plt.ylim(-5,105)
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# Save the plotted figure as .pngs
plt.savefig("Latitude vs Cloudiness.png")

# %%
 #Latitude vs. Wind Speed Plot
plt.scatter(weather_df["Lat"], weather_df["Wind Speed"], facecolor = "steelblue", edgecolor = "black")

plt.title("City Latitude vs. Wind Speed (mph) (04/01/20)")
plt.xlabel("Laitude")
plt.ylabel("Wind Speed (%)")
plt.ylim(-2,50)
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# Save the plotted figure as .pngs
plt.savefig("Latitude vs Wind Speed (mph).png")

# %%
 #Linear Regression
 # OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_hemisphere = weather_df.loc[weather_df["Lat"] >= 0]
southern_hemisphere = weather_df.loc[weather_df["Lat"] < 0]

# %%
#regression start for plots
def linear_agression(x,y):
    print(f"The r-squared is : {round(st.pearsonr(x, y)[0],2)}")
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    regress_values = x * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x, y)
    plt.plot(x,regress_values,"r-")
    return line_eq

# Define a fuction for annotating
def annotate(line_eq, a, b):
    plt.annotate(line_eq,(a,b),fontsize=15,color="red")

# %%
#Northern Hemisphere - Max Temp vs. Latitude Linear Regression
equation = linear_agression(northern_hemisphere["Lat"], northern_hemisphere["Max Temp"])

annotate(equation, 0, 0)

plt.title("Northern Hemisphere - Max Temp vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (F)")

# Save the figure
plt.savefig("Northern Hemisphere - Max Temp vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : -0.62

# %%
#Southern Hemisphere - Max Temp vs. Latitude Linear Regression
equation = linear_agression(southern_hemisphere["Lat"],southern_hemisphere["Max Temp"])

annotate(equation, -30, 50)

plt.title("Southern Hemisphere - Max Temp vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (F)")

# Save the figure
plt.savefig("Southern Hemisphere - Max Temp vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : 0.72

# %%
 #Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression
equation = linear_agression(northern_hemisphere["Lat"], northern_hemisphere["Humidity"])

annotate(equation, 40, 15)

plt.title("Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

# Save the figure
plt.savefig("Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : -0.09

# %%
#Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression
equation = linear_agression(southern_hemisphere["Lat"], southern_hemisphere["Humidity"])

annotate(equation, -40, 50)

plt.title("Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

# Save the figure
plt.savefig("Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : 0.14

# %%
 #Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression
equation = linear_agression(northern_hemisphere["Lat"], northern_hemisphere["Cloudiness"])

annotate(equation, 30, 40)

plt.title("Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

# Save the figure
plt.savefig("Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : -0.08

# %%
 #Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression
equation = linear_agression(southern_hemisphere["Lat"], southern_hemisphere["Cloudiness"])

annotate(equation, -30, 40)

plt.title("Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

# Save the figure
plt.savefig("Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : -0.03

# %%
 #Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
equation = linear_agression(northern_hemisphere["Lat"], northern_hemisphere["Wind Speed"])

annotate(equation, 40, 20)

plt.title("Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

# Save the figure
plt.savefig("Northern Hemisphere - Wind Speed vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : 0.02

# %%
#Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
equation = linear_agression(southern_hemisphere["Lat"], southern_hemisphere["Wind Speed"])

annotate(equation, -30, 15)

plt.title("Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

# Save the figure
plt.savefig("Southern Hemisphere - Wind Speed vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : 0.01
