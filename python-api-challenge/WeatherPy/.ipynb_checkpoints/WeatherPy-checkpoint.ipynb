# %%
#! pip install citipy

# %%
import matplotlib.pyplot as plt
import json
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from Config import weather_api_key

from citipy import citipy
output_data_file = "output_data/cities.csv"
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
 # List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 616

# %%
city_name_list = []
lat_list = []
lng_list = []
max_temp_list = []
humidity_list = []
cloudiness_list = []
wind_speed_list = []
country_list = []
date_list = []
index_counter = 0
set_counter = 1

# %%
#Perform a weather check on each city using a series of successive API calls.
#Include a print log of each city as it'sbeing processed (with the city number and city name).
print("Beginning Data Retrieval ")
print("-----------------------------")

base_url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{base_url}appid={weather_api_key}&units={units}&q="


# Cities
for index, city in enumerate(cities, start = 1):
    try:
        response = requests.get(query_url + city).json()
        city_name_list.append(response["name"])
        lat_list.append(response["coord"]["lat"])
        lng_list.append(response["coord"]["lon"])
        max_temp_list.append(response['main']['temp_max'])
        humidity_list.append(response["main"]["humidity"])
        cloudiness_list.append(response["clouds"]["all"])
        wind_speed_list.append(response["wind"]["speed"])
        country_list.append(response["sys"]["country"])
        date_list.append(response["dt"])
        if index_counter > 49:
            index_counter = 0
            set_counter = set_counter + 1
    
        else:
            index_counter = index_counter + 1
            
        print(f"Processing Record {index_counter} of Set {set_counter} : {city}") 
  
    except(KeyError, IndexError):
        
        print("City not found. Skipping...")

print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 : dikson
# Processing Record 2 of Set 1 : kerema
# Processing Record 3 of Set 1 : puerto ayora
# Processing Record 4 of Set 1 : acapulco
# Processing Record 5 of Set 1 : kysyl-syr
# Processing Record 6 of Set 1 : rikitea
# Processing Record 7 of Set 1 : xichang
# Processing Record 8 of Set 1 : vaini
# Processing Record 9 of Set 1 : hasaki
# Processing Record 10 of Set 1 : manavalakurichi
# Processing Record 11 of Set 1 : millau
# Processing Record 12 of Set 1 : tuktoyaktuk
# Processing Record 13 of Set 1 : pangnirtung
# Processing Record 14 of Set 1 : kapaa
# Processing Record 15 of Set 1 : manicore
# Processing Record 16 of Set 1 : susaki
# Processing Record 17 of Set 1 : sao joao da barra
# Processing Record 18 of Set 1 : laranjal paulista
# Processing Record 19 of Set 1 : castro
# Processing Record 20 of Set 1 : songadh
# Processing Record 21 of Set 1 : nyrob
# Processing Record 22 of Set 1 : punta arenas
# Processing Record 23 of Set 1 : saldanha
# Processing Record 24 of Set 1 : bathsheba
# City not found. Skipping...
# Processing Record 25 of Set 1 : klaksvik
# Processing Record 26 of Set 1 : east london
# Processing Record 27 of Set 1 : mataura
# Processing Record 28 of Set 1 : bethel
# Processing Record 29 of Set 1 : hohhot
# Processing Record 30 of Set 1 : petropavlovsk-kamchatskiy
# Processing Record 31 of Set 1 : pisco
# City not found. Skipping...
# Processing Record 32 of Set 1 : bluff
# Processing Record 33 of Set 1 : hobart
# Processing Record 34 of Set 1 : maumere
# Processing Record 35 of Set 1 : blythe
# Processing Record 36 of Set 1 : sobolevo
# Processing Record 37 of Set 1 : alice springs
# Processing Record 38 of Set 1 : avarua
# Processing Record 39 of Set 1 : yingcheng
# Processing Record 40 of Set 1 : saint george
# Processing Record 41 of Set 1 : hermanus
# Processing Record 42 of Set 1 : praia da vitoria
# Processing Record 43 of Set 1 : carutapera
# Processing Record 44 of Set 1 : flinders
# Processing Record 45 of Set 1 : adrar
# Processing Record 46 of Set 1 : edd
# Processing Record 47 of Set 1 : honggang
# Processing Record 48 of Set 1 : port macquarie
# Processing Record 49 of Set 1 : port elizabeth
# Processing Record 50 of Set 1 : elko
# Processing Record 0 of Set 2 : port alfred
# Processing Record 1 of Set 2 : qaanaaq
# Processing Record 2 of Set 2 : broome
# Processing Record 3 of Set 2 : hegra
# Processing Record 4 of Set 2 : arraial do cabo
# Processing Record 5 of Set 2 : mahebourg
# Processing Record 6 of Set 2 : hithadhoo
# Processing Record 7 of Set 2 : busselton
# Processing Record 8 of Set 2 : prado
# Processing Record 9 of Set 2 : cape town
# Processing Record 10 of Set 2 : yellowknife
# Processing Record 11 of Set 2 : ancud
# Processing Record 12 of Set 2 : mayor pablo lagerenza
# Processing Record 13 of Set 2 : kavaratti
# Processing Record 14 of Set 2 : terrace
# Processing Record 15 of Set 2 : oum hadjer
# Processing Record 16 of Set 2 : tura
# Processing Record 17 of Set 2 : sao jose da coroa grande
# Processing Record 18 of Set 2 : iqaluit
# Processing Record 19 of Set 2 : paamiut
# Processing Record 20 of Set 2 : jamestown
# Processing Record 21 of Set 2 : vanimo
# Processing Record 22 of Set 2 : luklukan
# City not found. Skipping...
# Processing Record 23 of Set 2 : trelew
# Processing Record 24 of Set 2 : mackenzie
# Processing Record 25 of Set 2 : ushuaia
# Processing Record 26 of Set 2 : lebu
# Processing Record 27 of Set 2 : la ronge
# Processing Record 28 of Set 2 : pascagoula
# Processing Record 29 of Set 2 : lorengau
# Processing Record 30 of Set 2 : norman wells
# Processing Record 31 of Set 2 : bunia
# Processing Record 32 of Set 2 : airai
# Processing Record 33 of Set 2 : sabha
# Processing Record 34 of Set 2 : kavieng
# Processing Record 35 of Set 2 : yeppoon
# Processing Record 36 of Set 2 : victoria
# Processing Record 37 of Set 2 : wadi musa
# Processing Record 38 of Set 2 : cairns
# Processing Record 39 of Set 2 : cabo san lucas
# Processing Record 40 of Set 2 : quelimane
# Processing Record 41 of Set 2 : oriximina
# Processing Record 42 of Set 2 : praia
# Processing Record 43 of Set 2 : grobina
# Processing Record 44 of Set 2 : adelaide
# Processing Record 45 of Set 2 : alberton
# Processing Record 46 of Set 2 : chipinge
# Processing Record 47 of Set 2 : anloga
# City not found. Skipping...
# Processing Record 48 of Set 2 : yantai
# Processing Record 49 of Set 2 : vardo
# Processing Record 50 of Set 2 : ukiah
# Processing Record 0 of Set 3 : souillac
# Processing Record 1 of Set 3 : ostrovnoy
# Processing Record 2 of Set 3 : dimitrovgrad
# Processing Record 3 of Set 3 : barrow
# Processing Record 4 of Set 3 : roald
# City not found. Skipping...
# Processing Record 5 of Set 3 : chuy
# Processing Record 6 of Set 3 : vao
# Processing Record 7 of Set 3 : upernavik
# Processing Record 8 of Set 3 : grand gaube
# Processing Record 9 of Set 3 : chongoyape
# Processing Record 10 of Set 3 : kagoro
# Processing Record 11 of Set 3 : nizwa
# Processing Record 12 of Set 3 : butaritari
# Processing Record 13 of Set 3 : pevek
# Processing Record 14 of Set 3 : georgetown
# Processing Record 15 of Set 3 : xuddur
# Processing Record 16 of Set 3 : bazarnyye mataki
# Processing Record 17 of Set 3 : tiksi
# Processing Record 18 of Set 3 : touros
# Processing Record 19 of Set 3 : kaitangata
# Processing Record 20 of Set 3 : caruray
# City not found. Skipping...
# Processing Record 21 of Set 3 : nikolskoye
# Processing Record 22 of Set 3 : lofthus
# Processing Record 23 of Set 3 : lompoc
# Processing Record 24 of Set 3 : ardesen
# Processing Record 25 of Set 3 : geraldton
# Processing Record 26 of Set 3 : erenhot
# Processing Record 27 of Set 3 : zhezkazgan
# Processing Record 28 of Set 3 : komsomolskiy
# Processing Record 29 of Set 3 : lazaro cardenas
# Processing Record 30 of Set 3 : gijon
# Processing Record 31 of Set 3 : bima
# Processing Record 32 of Set 3 : leningradskiy
# Processing Record 33 of Set 3 : padang
# Processing Record 34 of Set 3 : sarangani
# Processing Record 35 of Set 3 : kabompo
# Processing Record 36 of Set 3 : albany
# Processing Record 37 of Set 3 : tasiilaq
# Processing Record 38 of Set 3 : biak
# Processing Record 39 of Set 3 : kwakoa
# Processing Record 40 of Set 3 : khor
# Processing Record 41 of Set 3 : abha
# Processing Record 42 of Set 3 : bredasdorp
# Processing Record 43 of Set 3 : poum
# Processing Record 44 of Set 3 : kidal
# Processing Record 45 of Set 3 : lagoa
# Processing Record 46 of Set 3 : neiafu
# Processing Record 47 of Set 3 : namibe
# Processing Record 48 of Set 3 : aleksandrovsk-sakhalinskiy
# Processing Record 49 of Set 3 : pomabamba
# Processing Record 50 of Set 3 : ribeira grande
# Processing Record 0 of Set 4 : fortuna
# Processing Record 1 of Set 4 : berlevag
# Processing Record 2 of Set 4 : maraa
# Processing Record 3 of Set 4 : abilene
# Processing Record 4 of Set 4 : flin flon
# City not found. Skipping...
# Processing Record 5 of Set 4 : khartoum
# Processing Record 6 of Set 4 : qaqortoq
# Processing Record 7 of Set 4 : ayan
# Processing Record 8 of Set 4 : gilleleje
# Processing Record 9 of Set 4 : new norfolk
# Processing Record 10 of Set 4 : copala
# Processing Record 11 of Set 4 : mar del plata
# Processing Record 12 of Set 4 : roebourne
# City not found. Skipping...
# Processing Record 13 of Set 4 : serchhip
# Processing Record 14 of Set 4 : maldonado
# City not found. Skipping...
# Processing Record 15 of Set 4 : san cristobal
# Processing Record 16 of Set 4 : guerrero negro
# City not found. Skipping...
# Processing Record 17 of Set 4 : vostok
# Processing Record 18 of Set 4 : thompson
# Processing Record 19 of Set 4 : atuona
# Processing Record 20 of Set 4 : sorong
# Processing Record 21 of Set 4 : tres picos
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 22 of Set 4 : taltal
# Processing Record 23 of Set 4 : kamina
# Processing Record 24 of Set 4 : choma
# Processing Record 25 of Set 4 : viedma
# Processing Record 26 of Set 4 : katsuura
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 27 of Set 4 : bacolod
# Processing Record 28 of Set 4 : bua yai
# Processing Record 29 of Set 4 : mitsamiouli
# Processing Record 30 of Set 4 : axim
# Processing Record 31 of Set 4 : razdolnoye
# Processing Record 32 of Set 4 : hilo
# Processing Record 33 of Set 4 : ebeltoft
# Processing Record 34 of Set 4 : darlowo
# Processing Record 35 of Set 4 : mahina
# Processing Record 36 of Set 4 : carnarvon
# Processing Record 37 of Set 4 : pemangkat
# City not found. Skipping...
# Processing Record 38 of Set 4 : bengkulu
# Processing Record 39 of Set 4 : hongjiang
# Processing Record 40 of Set 4 : noshiro
# Processing Record 41 of Set 4 : muroto
# City not found. Skipping...
# Processing Record 42 of Set 4 : shar
# Processing Record 43 of Set 4 : necochea
# Processing Record 44 of Set 4 : mabaruma
# Processing Record 45 of Set 4 : launceston
# Processing Record 46 of Set 4 : ilulissat
# Processing Record 47 of Set 4 : ponta do sol
# Processing Record 48 of Set 4 : dondo
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 49 of Set 4 : cap malheureux
# Processing Record 50 of Set 4 : merauke
# Processing Record 0 of Set 5 : ust-omchug
# Processing Record 1 of Set 5 : savalou
# Processing Record 2 of Set 5 : takoradi
# Processing Record 3 of Set 5 : saint cloud
# Processing Record 4 of Set 5 : raga
# Processing Record 5 of Set 5 : metro
# Processing Record 6 of Set 5 : miracema do tocantins
# City not found. Skipping...
# Processing Record 7 of Set 5 : tautira
# Processing Record 8 of Set 5 : santa cruz del sur
# Processing Record 9 of Set 5 : grand forks
# Processing Record 10 of Set 5 : ibra
# Processing Record 11 of Set 5 : sechura
# Processing Record 12 of Set 5 : chokurdakh
# Processing Record 13 of Set 5 : mombetsu
# City not found. Skipping...
# Processing Record 14 of Set 5 : kahului
# Processing Record 15 of Set 5 : tabou
# Processing Record 16 of Set 5 : egvekinot
# Processing Record 17 of Set 5 : shimoda
# Processing Record 18 of Set 5 : torbay
# Processing Record 19 of Set 5 : longyearbyen
# Processing Record 20 of Set 5 : prainha
# Processing Record 21 of Set 5 : tazovskiy
# Processing Record 22 of Set 5 : saint-philippe
# Processing Record 23 of Set 5 : port hedland
# Processing Record 24 of Set 5 : bambous virieux
# Processing Record 25 of Set 5 : portland
# Processing Record 26 of Set 5 : tessalit
# Processing Record 27 of Set 5 : banfora
# Processing Record 28 of Set 5 : pacific grove
# Processing Record 29 of Set 5 : wewak
# Processing Record 30 of Set 5 : chara
# Processing Record 31 of Set 5 : aklavik
# Processing Record 32 of Set 5 : bytow
# Processing Record 33 of Set 5 : beaverlodge
# Processing Record 34 of Set 5 : north bend
# Processing Record 35 of Set 5 : along
# Processing Record 36 of Set 5 : obo
# Processing Record 37 of Set 5 : phan thiet
# Processing Record 38 of Set 5 : faanui
# Processing Record 39 of Set 5 : yangambi
# Processing Record 40 of Set 5 : cherskiy
# Processing Record 41 of Set 5 : pacocha
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 42 of Set 5 : arcata
# Processing Record 43 of Set 5 : magadan
# Processing Record 44 of Set 5 : lixourion
# Processing Record 45 of Set 5 : southwick
# Processing Record 46 of Set 5 : yumen
# Processing Record 47 of Set 5 : plainview
# Processing Record 48 of Set 5 : onguday
# Processing Record 49 of Set 5 : salym
# Processing Record 50 of Set 5 : fort nelson
# Processing Record 0 of Set 6 : ranong
# Processing Record 1 of Set 6 : husavik
# Processing Record 2 of Set 6 : shenjiamen
# Processing Record 3 of Set 6 : dobrun
# Processing Record 4 of Set 6 : tuatapere
# Processing Record 5 of Set 6 : townsville
# Processing Record 6 of Set 6 : brae
# Processing Record 7 of Set 6 : baghdad
# Processing Record 8 of Set 6 : qui nhon
# Processing Record 9 of Set 6 : lufkin
# Processing Record 10 of Set 6 : hobyo
# Processing Record 11 of Set 6 : havelock
# Processing Record 12 of Set 6 : huarmey
# Processing Record 13 of Set 6 : assiniboia
# Processing Record 14 of Set 6 : florianopolis
# Processing Record 15 of Set 6 : batagay-alyta
# Processing Record 16 of Set 6 : narsaq
# Processing Record 17 of Set 6 : khatanga
# Processing Record 18 of Set 6 : severobaykalsk
# City not found. Skipping...
# Processing Record 19 of Set 6 : shingu
# Processing Record 20 of Set 6 : abdanan
# Processing Record 21 of Set 6 : myaundzha
# Processing Record 22 of Set 6 : port hardy
# Processing Record 23 of Set 6 : akyab
# Processing Record 24 of Set 6 : clyde river
# Processing Record 25 of Set 6 : ripiceni
# Processing Record 26 of Set 6 : constantine
# City not found. Skipping...
# Processing Record 27 of Set 6 : hershey
# Processing Record 28 of Set 6 : kirkland lake
# Processing Record 29 of Set 6 : agadir
# Processing Record 30 of Set 6 : hargeysa
# Processing Record 31 of Set 6 : lafayette
# Processing Record 32 of Set 6 : port blair
# Processing Record 33 of Set 6 : marsta
# Processing Record 34 of Set 6 : mayo
# Processing Record 35 of Set 6 : tokoroa
# Processing Record 36 of Set 6 : malmesbury
# City not found. Skipping...
# Processing Record 37 of Set 6 : yarmouth
# Processing Record 38 of Set 6 : ahipara
# Processing Record 39 of Set 6 : shamkhal
# Processing Record 40 of Set 6 : altamirano
# Processing Record 41 of Set 6 : saint-georges
# Processing Record 42 of Set 6 : dunedin
# City not found. Skipping...
# Processing Record 43 of Set 6 : kushima
# Processing Record 44 of Set 6 : kozhva
# Processing Record 45 of Set 6 : oranjemund
# Processing Record 46 of Set 6 : irtyshskiy
# Processing Record 47 of Set 6 : isangel
# Processing Record 48 of Set 6 : port-gentil
# Processing Record 49 of Set 6 : marzuq
# Processing Record 50 of Set 6 : punta cardon
# Processing Record 0 of Set 7 : derzhavinsk
# City not found. Skipping...
# Processing Record 1 of Set 7 : olafsvik
# City not found. Skipping...
# Processing Record 2 of Set 7 : verkhoyansk
# Processing Record 3 of Set 7 : panaba
# Processing Record 4 of Set 7 : omboue
# Processing Record 5 of Set 7 : saint-louis
# Processing Record 6 of Set 7 : karratha
# Processing Record 7 of Set 7 : eureka
# Processing Record 8 of Set 7 : point pedro
# Processing Record 9 of Set 7 : sabang
# Processing Record 10 of Set 7 : bandundu
# City not found. Skipping...
# Processing Record 11 of Set 7 : kouroussa
# Processing Record 12 of Set 7 : grants
# Processing Record 13 of Set 7 : killam
# Processing Record 14 of Set 7 : northam
# Processing Record 15 of Set 7 : khandyga
# City not found. Skipping...
# Processing Record 16 of Set 7 : kharp
# Processing Record 17 of Set 7 : nioro
# Processing Record 18 of Set 7 : cidreira
# Processing Record 19 of Set 7 : saskylakh
# Processing Record 20 of Set 7 : haukipudas
# Processing Record 21 of Set 7 : esperance
# Processing Record 22 of Set 7 : saint-joseph
# Processing Record 23 of Set 7 : harper
# Processing Record 24 of Set 7 : severo-kurilsk
# Processing Record 25 of Set 7 : namatanai
# City not found. Skipping...
# Processing Record 26 of Set 7 : saint-pierre
# Processing Record 27 of Set 7 : kruisfontein
# Processing Record 28 of Set 7 : grindavik
# City not found. Skipping...
# Processing Record 29 of Set 7 : sorland
# Processing Record 30 of Set 7 : constitucion
# City not found. Skipping...
# Processing Record 31 of Set 7 : byron bay
# Processing Record 32 of Set 7 : half moon bay
# Processing Record 33 of Set 7 : makaryev
# Processing Record 34 of Set 7 : windhoek
# Processing Record 35 of Set 7 : gallup
# Processing Record 36 of Set 7 : moron
# Processing Record 37 of Set 7 : atambua
# Processing Record 38 of Set 7 : mandera
# Processing Record 39 of Set 7 : sahaswan
# Processing Record 40 of Set 7 : muros
# Processing Record 41 of Set 7 : talas
# Processing Record 42 of Set 7 : drumheller
# Processing Record 43 of Set 7 : ayr
# Processing Record 44 of Set 7 : ndende
# Processing Record 45 of Set 7 : hay river
# Processing Record 46 of Set 7 : tupik
# Processing Record 47 of Set 7 : rio gallegos
# Processing Record 48 of Set 7 : wattegama
# Processing Record 49 of Set 7 : abu samrah
# Processing Record 50 of Set 7 : itabira
# Processing Record 0 of Set 8 : gawler
# Processing Record 1 of Set 8 : mitu
# Processing Record 2 of Set 8 : sandwick
# Processing Record 3 of Set 8 : dongsheng
# Processing Record 4 of Set 8 : san francisco del mar
# Processing Record 5 of Set 8 : los llanos de aridane
# City not found. Skipping...
# Processing Record 6 of Set 8 : provideniya
# Processing Record 7 of Set 8 : yulara
# Processing Record 8 of Set 8 : qasigiannguit
# Processing Record 9 of Set 8 : hamilton
# Processing Record 10 of Set 8 : apricena
# Processing Record 11 of Set 8 : pinugay
# Processing Record 12 of Set 8 : nanortalik
# Processing Record 13 of Set 8 : yenagoa
# Processing Record 14 of Set 8 : vogar
# City not found. Skipping...
# Processing Record 15 of Set 8 : salalah
# Processing Record 16 of Set 8 : vallenar
# Processing Record 17 of Set 8 : uarini
# Processing Record 18 of Set 8 : segezha
# Processing Record 19 of Set 8 : la union
# Processing Record 20 of Set 8 : porto walter
# Processing Record 21 of Set 8 : sao gabriel da cachoeira
# Processing Record 22 of Set 8 : iquique
# Processing Record 23 of Set 8 : alofi
# Processing Record 24 of Set 8 : hualmay
# Processing Record 25 of Set 8 : boissevain
# Processing Record 26 of Set 8 : gurlan
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 27 of Set 8 : cayenne
# Processing Record 28 of Set 8 : were ilu
# Processing Record 29 of Set 8 : severomuysk
# Processing Record 30 of Set 8 : malanje
# Processing Record 31 of Set 8 : horsham
# Processing Record 32 of Set 8 : dhule
# Processing Record 33 of Set 8 : lasa
# Processing Record 34 of Set 8 : asfi
# Processing Record 35 of Set 8 : trinidad
# Processing Record 36 of Set 8 : asau
# Processing Record 37 of Set 8 : cavalcante
# Processing Record 38 of Set 8 : havoysund
# Processing Record 39 of Set 8 : bolotnoye
# Processing Record 40 of Set 8 : odweyne
# Processing Record 41 of Set 8 : fairbanks
# City not found. Skipping...
# Processing Record 42 of Set 8 : sayyan
# Processing Record 43 of Set 8 : lima
# Processing Record 44 of Set 8 : deputatskiy
# Processing Record 45 of Set 8 : bilma
# Processing Record 46 of Set 8 : abatskoye
# Processing Record 47 of Set 8 : ust-kuyga
# Processing Record 48 of Set 8 : llano largo
# Processing Record 49 of Set 8 : rawson
# Processing Record 50 of Set 8 : maravilha
# Processing Record 0 of Set 9 : korba
# Processing Record 1 of Set 9 : ishikari
# Processing Record 2 of Set 9 : kaduna
# City not found. Skipping...
# Processing Record 3 of Set 9 : mata
# Processing Record 4 of Set 9 : hervey bay
# Processing Record 5 of Set 9 : orange cove
# City not found. Skipping...
# Processing Record 6 of Set 9 : yuncheng
# Processing Record 7 of Set 9 : birin
# Processing Record 8 of Set 9 : ferrol
# Processing Record 9 of Set 9 : sovetskaya gavan
# Processing Record 10 of Set 9 : kudat
# Processing Record 11 of Set 9 : chudniv
# Processing Record 12 of Set 9 : najran
# Processing Record 13 of Set 9 : nogales
# Processing Record 14 of Set 9 : suntar
# Processing Record 15 of Set 9 : veinticinco de mayo
# Processing Record 16 of Set 9 : plettenberg bay
# Processing Record 17 of Set 9 : rondonopolis
# Processing Record 18 of Set 9 : walvis bay
# Processing Record 19 of Set 9 : saint-ambroise
# Processing Record 20 of Set 9 : surt
# Processing Record 21 of Set 9 : melchor de mencos
# Processing Record 22 of Set 9 : ongandjera
# Processing Record 23 of Set 9 : listvyanskiy
# Processing Record 24 of Set 9 : gairatganj
# Processing Record 25 of Set 9 : gaoua
# Processing Record 26 of Set 9 : saginaw
# Processing Record 27 of Set 9 : genhe
# City not found. Skipping...
# Processing Record 28 of Set 9 : nishihara
# Processing Record 29 of Set 9 : gasa
# City not found. Skipping...
# Processing Record 30 of Set 9 : kanturk
# City not found. Skipping...
# Processing Record 31 of Set 9 : la puebla del rio
# City not found. Skipping...
# Processing Record 32 of Set 9 : batemans bay
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 33 of Set 9 : mage
# Processing Record 34 of Set 9 : evensk
# Processing Record 35 of Set 9 : gorontalo
# Processing Record 36 of Set 9 : tamayo
# Processing Record 37 of Set 9 : eyrarbakki
# Processing Record 38 of Set 9 : sitka
# Processing Record 39 of Set 9 : samoded
# Processing Record 40 of Set 9 : port lavaca
# Processing Record 41 of Set 9 : pringsewu
# City not found. Skipping...
# Processing Record 42 of Set 9 : ust-karsk
# Processing Record 43 of Set 9 : port lincoln
# Processing Record 44 of Set 9 : acarau
# Processing Record 45 of Set 9 : ludvika
# City not found. Skipping...
# Processing Record 46 of Set 9 : biskupiec
# Processing Record 47 of Set 9 : umm lajj
# Processing Record 48 of Set 9 : kroya
# Processing Record 49 of Set 9 : gonbad-e qabus
# City not found. Skipping...
# Processing Record 50 of Set 9 : mount gambier
# Processing Record 0 of Set 10 : orcopampa
# City not found. Skipping...
# Processing Record 1 of Set 10 : grootfontein
# Processing Record 2 of Set 10 : bellevue
# Processing Record 3 of Set 10 : amahai
# Processing Record 4 of Set 10 : mayumba
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 5 of Set 10 : santa helena
# Processing Record 6 of Set 10 : maningrida
# Processing Record 7 of Set 10 : olinda
# Processing Record 8 of Set 10 : gravenhurst
# Processing Record 9 of Set 10 : talnakh
# Processing Record 10 of Set 10 : soyo
# Processing Record 11 of Set 10 : luanda
# Processing Record 12 of Set 10 : ambon
# Processing Record 13 of Set 10 : kudahuvadhoo
# Processing Record 14 of Set 10 : olden
# City not found. Skipping...
# Processing Record 15 of Set 10 : san patricio
# Processing Record 16 of Set 10 : marystown
# Processing Record 17 of Set 10 : tecoanapa
# Processing Record 18 of Set 10 : fort wellington
# Processing Record 19 of Set 10 : vila
# Processing Record 20 of Set 10 : kiunga
# Processing Record 21 of Set 10 : ambulu
# Processing Record 22 of Set 10 : kodiak
# Processing Record 23 of Set 10 : lyaskelya
# Processing Record 24 of Set 10 : coihueco
# Processing Record 25 of Set 10 : pingliang
# City not found. Skipping...
# Processing Record 26 of Set 10 : norrtalje
# Processing Record 27 of Set 10 : saint-francois
# Processing Record 28 of Set 10 : luneville
# Processing Record 29 of Set 10 : sola
# Processing Record 30 of Set 10 : zyryanka
# City not found. Skipping...
# Processing Record 31 of Set 10 : burriana
# Processing Record 32 of Set 10 : preobrazheniye
# Processing Record 33 of Set 10 : opuwo
# Processing Record 34 of Set 10 : vidisha
# Processing Record 35 of Set 10 : codrington
# City not found. Skipping...
# Processing Record 36 of Set 10 : sibolga
# Processing Record 37 of Set 10 : majene
# Processing Record 38 of Set 10 : nijar
# Processing Record 39 of Set 10 : iraquara
# Processing Record 40 of Set 10 : zhigalovo
# City not found. Skipping...
# Processing Record 41 of Set 10 : ugoofaaru
# Processing Record 42 of Set 10 : hambantota
# Processing Record 43 of Set 10 : sokoni
# Processing Record 44 of Set 10 : post falls
# Processing Record 45 of Set 10 : hami
# Processing Record 46 of Set 10 : krabi
# Processing Record 47 of Set 10 : luderitz
# City not found. Skipping...
# Processing Record 48 of Set 10 : solnechnyy
# Processing Record 49 of Set 10 : comodoro rivadavia
# Processing Record 50 of Set 10 : new waterford
# Processing Record 0 of Set 11 : juneau
# Processing Record 1 of Set 11 : camabatela
# Processing Record 2 of Set 11 : nyzhnya duvanka
# Processing Record 3 of Set 11 : bridlington
# City not found. Skipping...
# Processing Record 4 of Set 11 : urengoy
# City not found. Skipping...
# Processing Record 5 of Set 11 : santa lucia
# Processing Record 6 of Set 11 : el alto
# Processing Record 7 of Set 11 : uribia
# Processing Record 8 of Set 11 : kaeo
# Processing Record 9 of Set 11 : severnoye
# Processing Record 10 of Set 11 : okhotsk
# Processing Record 11 of Set 11 : synya
# City not found. Skipping...
# Processing Record 12 of Set 11 : carupano
# City not found. Skipping...
# Processing Record 13 of Set 11 : seoni malwa
# Processing Record 14 of Set 11 : ruwi
# City not found. Skipping...
# Processing Record 15 of Set 11 : prachuap khiri khan
# Processing Record 16 of Set 11 : gamba
# Processing Record 17 of Set 11 : nalut
# Processing Record 18 of Set 11 : camacha
# City not found. Skipping...
# Processing Record 19 of Set 11 : port keats
# Processing Record 20 of Set 11 : anadyr
# Processing Record 21 of Set 11 : badarwas
# Processing Record 22 of Set 11 : sinnamary
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 23 of Set 11 : aksu
# Processing Record 24 of Set 11 : manokwari
# City not found. Skipping...
# Processing Record 25 of Set 11 : ullapool
# Processing Record 26 of Set 11 : williamsburg
# Processing Record 27 of Set 11 : cap-chat
# Processing Record 28 of Set 11 : tynda
# Processing Record 29 of Set 11 : nawa
# Processing Record 30 of Set 11 : sabya
# Processing Record 31 of Set 11 : yerbogachen
# Processing Record 32 of Set 11 : meiktila
# Processing Record 33 of Set 11 : visby
# Processing Record 34 of Set 11 : sangmelima
# City not found. Skipping...
# Processing Record 35 of Set 11 : samarai
# Processing Record 36 of Set 11 : haines junction
# Processing Record 37 of Set 11 : ouadda
# Processing Record 38 of Set 11 : wladyslawowo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#Export the city data into a .csv.
#Display the DataFrame

# %%
 #Inspect the data and remove the cities where the humidity > 100%.

#Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %%
# Extract relevant fields from the data frame


# Export the City_Data into a csv

# %%
 #Latitude vs. Temperature Plot

# %%
#Latitude vs. Humidity Plot

# %%
 #Latitude vs. Cloudiness Plot

# %%
 #Latitude vs. Wind Speed Plot

# %%
 #Linear Regression
 # OPTIONAL: Create a function to create Linear Regression plots
# Out:
#   File "<ipython-input-16-8c865bee6b7e>", line 1
#     Linear Regression
#                     ^
# SyntaxError: invalid syntax

# %%
# Create Northern and Southern Hemisphere DataFrames

# %%
#Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
 #Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
 #Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
 #Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
 #Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
